# %% [markdown]
# # Task : String

# %%
#1. **Create a String**:
 #  - Create a string variable named `greeting` that contains the word "Hello".
greeting = 'Hello'
print(greeting)

# %%
#2. **Accessing Characters**:
#   - How would you access the first character of a string stored in a variable named `city`?
city='Bangalore'
res=city[0]
print(res)

# %%
#3. **String Slicing**:
# - Write a command to extract the substring "world" from the string "Hello world".
var='Hello world'
res=var[6:]
print(res)

# %%
#4. **String Concatenation**:
 #  - How would you concatenate two strings, `first_name` and `last_name`, with a space between them to form a full name?
first_name='first_name'
last_name='last_name'
full_name=(first_name+" "+"last_name")
print(full_name)

# %%
#5. **Converting to Uppercase**:
str="Python is my Favorite"
res=str.upper()
print(res)

# %%
#6. **Trimming Whitespace**:
#- Remove leading and trailing whitespaces from the string "  hello  ".
trim="  hello  "
result_trim=trim.strip()
print(result_trim)

# %%
#7.**String Replacement**:
  # - Replace all occurrences of 'dog' with 'cat' in the string "I love my dog".
repl="I love my dog"
res_repl=repl.replace("dog","cat")
print(res_repl)

# %%
#8.**String Length**:
 #  - Find the length of the string "data science".
str="data science"
res_str=len(str)
print(res_str)

# %%
#9.**Repeating Strings**:
# Repeat the string "ha" 5 times.
print("ha \n"*5)

# %%
#1#10.. **Checking Substring Presence**:
   # - Check if the substring "learn" is present in the string "Time to learn Python".
substr="Time to learn Python"
if "learn" in substr:
    print("learn is find in the string:  {}".format(substr))
else:
    print("word is not found in the string {}".format(substr))

# %%
#11.**Splitting a String**:
#- Split the string "one, two, three" into a list, using comma as a delimiter.
sen ="one, two, three"
sen_res=sen.split()
print(sen_res)

# %%
#12. **Joining a List of Strings**:
  #- Join the list `['Python', 'is', 'awesome']` into a single string, with spaces separating the words.
joining=['Python', 'is', 'awesome']
result_join=" ".join(joining)
print(result_join)

# %%
#13. **String Formatting with `format()`**:
#- Use the `format()` method to insert the variable `name` into the string template "My name is {}".
name="Reshmi"
print("My name is {0}".format(name))

# %%
#14.**Using f-strings for Formatting**: - Rewrite the above task using an f-string.
name="Reshmi"
print(f"My name is {name}")

# %%
#15. **Escape Characters**:
#-How would you include a double quote character inside a string literal?
name='''My Name is "Reshmi""'''
print(name)

# %%
#16.**Finding a Substring**:
#- Find the index of the first occurrence of 'Python' in the string "Learning Python programming".
substr="Learning Python programming"
res_substr=substr.find('Python')
print(res_substr)

# %%
#17. **String to List of Characters**:
#- Convert the string "hello" into a list of characters.
conv="hello"
res_conv=list("hello")
print(res_conv)

# %%
#18. **Removing a Specific Character**:
  #  - Remove all instances of the letter 'a' from the string "banana".
rem='banana'
rem_res=rem.replace('a',"")
print(rem_res)

# %%
#19. **Palindrome Check**:
#- How would you check if a string is a palindrome?
pali=input("Enter the string :")
if (pali == pali[::-1]):
    print("The given string is palindrome")
else:
    print("The given string is not Palindrome")

# %%
#20.**Character Frequency Count**:
 #Count how many times the letter 'i' appears in the string "Mississippi".
cnt="Mississippi"
res_cnt=cnt.count('i')
print(res_cnt)
