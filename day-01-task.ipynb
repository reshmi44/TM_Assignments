# %%
#1. What is the data type of the value `42` in Python?
a=42
print(type(a))
# Out:
# <class 'int'>

# %%
#2. Give an example of a string data type in Python.
a="Hello World"
print(type(a),a)
# Out:
# <class 'str'> Hello World

# %%
#3. Explain the difference between a list and a tuple in Python.
#List is mutable and tuples are immutable

# %%
#4. How do you define a dictionary in Python?
var={"name":"Reshmi","Age":30}
print(var.values())
# Out:
# dict_values(['Reshmi', 30])

# %%
#5. What does the `None` data type represent in Python?
#None is not a datatype.

# %%
#6. What is the result of `5 + 3` using Python's addition operator?
print(5+3)
# Out:
# 8

# %%
#7. How do you perform exponentiation in Python?
print(5**2)
# Out:
# 25

# %%
#8. Explain the difference between the `/` and `//` operators in Python.
#-/ gives the decimal values when divided.// gives the whole number when divided-Floor division

# %%
#9. What is the output of `10 % 3` using Python's modulo operator?
print(10%9)
# Out:
# 1

# %%
#10. How do you calculate the floor division of two numbers in Python?
#Ans=//

# %%
#16. What is the output of `5 + 3 * 2` in Python?
print(5+3*2)
# Out:
# 11

# %%
#17. How do you concatenate two strings in Python?
str1="Hello"
str2="World!"
print(str1+" "+str2)
# Out:
# Hello World!

# %%
#18. Write a Python code snippet to check if a given number is even.
num=int(input("Enter the number"))
if num%2==0:
  print("The number {} is an even number".format(num))
else:
  print("The number {} is an odd number".format(num))
# Out:
# Enter the number 23
# The number 23 is an odd number

# %%
#19. What is the difference between `==` and `=` in Python?
#(== is an Arithmatic Operator and = is to assign values)

# %%
#20. How do you access the value associated with a specific key in a dictionary in Python?
car = {
"brand": "Ford",
"model": "Mustang",
"year": 1964
}

x = car.values()
print(x)
# Out:
# dict_values(['Ford', 'Mustang', 1964])
